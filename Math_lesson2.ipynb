# %% [markdown]
# __1.__ Представьте в виде __несократимой__ рациональной дроби:
#
# ### $$а)\,\,\, 0.(216);$$
#
# ### $$б)\,\,\, 1.0(01).$$

# %% [markdown]
# ### a)
#
# $$a=0.(216)$$
#
# $$1000a=216 + a$$
# $$a=\frac{216}{999}=\frac{8}{37}$$
# $$0.(216) = \frac{8}{37}$$

# %%
print(8/37)
# Out:
# 0.21621621621621623

# %% [markdown]
# ### b)
#
# $$a=0.(01)$$
# $$100a=1+a$$
# $$a=\frac{1}{99}$$
#
# $$b=1.0(01)$$
# $$10b = 10+\frac{1}{99}$$
# $$b=\frac{991}{990}=1\frac{1}{990}$$
# $$1.0(01) = \frac{991}{990}$$

# %%
print(991/990)
# Out:
# 1.001010101010101

# %% [markdown]
# __3.__ Проверьте любым способ, является ли данные логические формулы тавтологией:
#
# ### $$a)\,\,\, (A \vee B) \rightarrow (B \vee\overline A)$$
# ### $$б)\,\,\, A \rightarrow (A \vee (\overline B \wedge A))$$

# %% [markdown]
# ### a)
#
#  <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$A \vee B$</th><th>$\overline A$</th><th>$\overline A\vee B$</th><th>$(A \vee B) \rightarrow (\overline A\vee B)$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$0$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$1$</td><td>$0$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>
# Формула не является тавтологией, т.к. при значении А = 1 и B = 0 дает ложный результат

# %% [markdown]
# ### b)
#
# $$ A \rightarrow (A \vee (\overline B \wedge A)) =  A \rightarrow A$$
# Формула является тавтологией, т.к. при любых значениях А дает положительный результат

# %% [markdown]
# __4.__ Сформулируйте словесно высказывания:
# ### $$a)\,\,\, (\overline A \vee B) \rightarrow \overline C$$
# ### $$б)\,\,\, C \rightarrow (A \vee \overline B)$$
#
# - $A:\,\,\,$ сегодня светит солнце;
# - $B:\,\,\,$ сегодня сыро;
# - $C:\,\,\,$ я поеду на дачу.

# %% [markdown]
# a) Если сегодня не светит солнце или сыро, то я не поеду на дачу
#
# б) Если я поеду на дачу, значит сегодня светит солнце или не сыро

# %% [markdown]
# __5.__  Пользуясь правилом построения противоположного высказывания, запишите утверждения, противоположные следующим:
#
# a) На любом курсе каждого факультета есть студенты, сдающие все экзамены на «отлично».
#
# б) В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой пуговице одежды которого вмонтирован микрофон.

# %% [markdown]
# a) высказывание:  На $\forall$ курсе $\forall$ факультета $\exists$ студенты, сдающие $\forall$ экзамены на "отлично"
#
# противоположное: Есть курсы на некоторых факультетах, где все студенты сдают некоторые экзамены не на отлично:
# $\exists$ курсы на $\exists$ факультетах, где $\forall$ студенты сдают $\exists$ экзамены не на отлично

# %% [markdown]
# б) высказывание:  В $\forall$ самолете на рейсе Вашингтон-Москва $\exists$ хотя бы один сотрудник силовых органов, в $\forall$ пуговице одежды которого вмонтирован микрофон
#
# противоположное: Есть самолеты на рейсе Вашингтон-Москва, где у всех сотрудников силовых органов в некоторые пуговицы не вмонтирован микрофон. $\exists$ самолеты на рейсе Вашингтон-Москва, где у $\forall$ сотрудников силовых органов в $\exists$ пуговицв не вмонтирован микрофон

# %% [markdown]
# __6*.__ Прочитайте высказывания, установите их истинность и постройте противоположное высказывание:
#
# ### $$a)\,\,\, \forall x\in\mathbb{R}\,\,\,\exists X\in\mathbb{R}:\,\,\, X>x;$$
# ### $$б)\,\,\, \forall y\in\Bigl[0; \frac{\pi}{2}\Bigr]\,\,\,\exists \varepsilon>0:\,\,\, \sin y<\sin(y+\varepsilon);$$
# ### $$в)\,\,\, \forall y\in\Bigl[0; \frac{\pi}{2}\Bigr)\,\,\,\exists \varepsilon>0:\,\,\, \cos y>\cos(y+\varepsilon).$$

# %% [markdown]
# a) для всех х, принадлежащих к множеству действительных чисел, есть некое множество Х, принадлежащее к множеству действительных чисел, когда множество X больше элемента х.
#
# противоположное: $$a)\,\,\, \exists x\in\mathbb{R}\,\,\,\forall X\in\mathbb{R}:\,\,\, X\leq x;$$

# %% [markdown]
# б) для любого y, принадлежащего к отрезку от 0 включительно до $\pi$ /2 включительно, есть $\varepsilon$>0, при котором синус у меньше синуса суммы у и $\varepsilon$
#
# противоположное:
# $$\,\,\, \exists y\in\Bigl[0; \frac{\pi}{2}\Bigr]\,\,\,\forall \varepsilon>0:\,\,\, \sin y\geq\sin(y+\varepsilon)$$

# %% [markdown]
# в) для любого y, принадлежащего к отрезку от 0 включительно до $\pi$ /2 исключительно, есть $\varepsilon$>0, при котором косинус у больше косинуса суммы у и $\varepsilon$
#
# противоположное:
# $$\,\,\, \exists y\in\Bigl[0; \frac{\pi}{2}\Bigr)\,\,\,\forall \varepsilon>0:\,\,\, \cos y\leq\cos(y+\varepsilon)$$

# %% [markdown]
# __2*.__ Пусть $x =\frac{2}{21}$. Известно, что для некоторого натурального $k$ число $x$ записывается в $k$ - ичной системе счисления как $0.(13)_k = 0, 131313..._k$. Найдите $k$.

# %% [markdown]
# приведем 0.(13) к виду рациональной дроби:
# $$a=0.(13)$$
# $$100a = 13+a$$
# $$a=\frac{13}{99}$$

# %% [markdown]
# в итоге у меня не получилось точно вычислить основание системы, в которой 13/99 может быть равно 2/21. Самое близкое натуральное число - число 13.
# Решение: округляем 0.(13) до 0.13. Получается:
# $$0 + 1 * \frac{1}{k} + 3 * \frac{1}{k^2} = \frac{2}{21}$$
# $$\frac{1}{k} + \frac{3}{k^2} = \frac{2}{21}$$
# $$ \frac{k+3}{k^2} - \frac{2}{21} = 0 $$
# $$ 21k+63-2k^2 = 0$$
# $$ D = 441+504 = 945$$
# $$ \frac{-21 +- \sqrt{945}}{-4} = k_1,_2$$
# в качестве корня 945 возьмем ближайшее натуральное число 31 и найдем положительное значение k:
# $$ k = \frac{-52}{-4} = 13 $$

# %% [markdown]
# При другом способе решения, без округлений, у меня получилось отрицательное k:
# $$\frac{13_k}{99_k} = \frac{2}{21}$$
# $$\frac{1 * k + 3}{9 * k + 9} = \frac{2}{21}$$
# $$\frac{21k + 63 - 18k - 18}{21(9k+9)} = 0$$
# $$ \frac{7k+21-6k-6}{7(9k+9)} = 0$$
# $$ k + 15 = 0$$
# $$ k = -15$$
